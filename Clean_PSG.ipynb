# %%
import pandas as pd
import numpy as np

# %%
psg = pd.read_csv("PSG.csv", encoding='ISO-8859-1')
psg.head()
# Out:
#              Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Playing Time  \
# 0                Player     Nation        Pos        Age           MP
# 1  Gianluigi Donnarumma     it ITA         GK     24-077           34
# 2            Marquinhos     br BRA         DF     28-364           30
# 3          Lionel Messi     ar ARG       FWMF     35-323           28
# 4         Kylian Mbappé     fr FRA         FW     24-144           30
#
#   Playing Time.1 Playing Time.2 Playing Time.3 Performance Performance.1  ...  \
# 0         Starts            Min            90s         Gls           Ast  ...
# 1             34           3060           34.0           0             0  ...
# 2             28           2527           28.1           2             0  ...
# 3             28           2477           27.5          15            15  ...
# 4             28           2458           27.3          24             4  ...
#
#   Per 90 Minutes.2 Per 90 Minutes.3 Per 90 Minutes.4 Per 90 Minutes.5  \
# 0              G+A             G-PK           G+A-PK               xG
# 1             0.00             0.00             0.00             0.00
# 2             0.07             0.07             0.07             0.07
# 3             1.09             0.55             1.09             0.51
# 4             1.03             0.81             0.95             0.82
#
#   Per 90 Minutes.6 Per 90 Minutes.7 Per 90 Minutes.8 Per 90 Minutes.9  \
# 0              xAG           xG+xAG             npxG         npxG+xAG
# 1             0.00             0.00             0.00             0.00
# 2             0.02             0.09             0.07             0.09
# 3             0.43             0.94             0.51             0.94
# 4             0.25             1.07             0.70             0.95
#
#   Unnamed: 33 -additional
# 0     Matches       -9999
# 1     Matches    08f5afaa
# 2     Matches    d5f2f82b
# 3     Matches    d70ce98e
# 4     Matches    42fd9c7f
#
# [5 rows x 35 columns]

# %%
#supprimer colonnes inutiles

psg = psg.loc[:, ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3']]
psg.head()
# Out:
#              Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0                Player     Nation        Pos        Age
# 1  Gianluigi Donnarumma     it ITA         GK     24-077
# 2            Marquinhos     br BRA         DF     28-364
# 3          Lionel Messi     ar ARG       FWMF     35-323
# 4         Kylian Mbappé     fr FRA         FW     24-144

# %%
#changement du nom des colonnes
psg.columns = ['Player', 'Nation', 'Pos', 'Age']
psg.head()
# Out:
#                  Player  Nation   Pos     Age
# 0                Player  Nation   Pos     Age
# 1  Gianluigi Donnarumma  it ITA    GK  24-077
# 2            Marquinhos  br BRA    DF  28-364
# 3          Lionel Messi  ar ARG  FWMF  35-323
# 4         Kylian Mbappé  fr FRA    FW  24-144

# %%
#suppression de la première ligne

psg = psg.drop(0)
psg.head(50)
# Out:
#                     Player  Nation   Pos     Age
# 1     Gianluigi Donnarumma  it ITA    GK  24-077
# 2               Marquinhos  br BRA    DF  28-364
# 3             Lionel Messi  ar ARG  FWMF  35-323
# 4            Kylian Mbappé  fr FRA    FW  24-144
# 5             Sergio Ramos  es ESP    DF  37-044
# 6                  Vitinha  pt POR    MF  23-089
# 7           Danilo Pereira  pt POR  DFMF  31-246
# 8           Marco Verratti  it ITA    MF  30-189
# 9            Achraf Hakimi  ma MAR  DFMF  24-190
# 10        Fabián Ruiz Peña  es ESP    MF  27-040
# 11             Nuno Mendes  pt POR    DF  20-328
# 12                  Neymar  br BRA  MFFW  31-097
# 13             Juan Bernat  es ESP    DF  30-073
# 14            Carlos Soler  es ESP    MF  26-131
# 15           Nordi Mukiele  fr FRA    DF  25-193
# 16            Hugo Ekitike  fr FRA    FW  20-327
# 17        Presnel Kimpembe  fr FRA    DF  27-273
# 18      Warren Zaire-Emery  fr FRA  MFDF  17-066
# 19          Renato Sanches  pt POR    MF  25-268
# 20  El Chadaille Bitshiabu  fr FRA    DF  17-362
# 21        Timothee Pembele  fr FRA    DF  20-246
# 22           Pablo Sarabia  es ESP  FWMF  31-002
# 23           Ismaël Gharbi  es ESP  MFFW  19-033
# 24         Leandro Paredes  ar ARG    MF  28-318
# 25            Ilyes Housni  fr FRA    FW  17-364
# 26            Abdou Diallo  sn SEN    DF  27-009
# 27      Nehemiah Fernandez  fr FRA    DF  18-153
# 28       Arnaud Kalimuendo  fr FRA    FW  21-113
# 29              Ayman Kari  fr FRA    MF  18-175
# 30               Hugo Lamy  fr FRA    DF  19-117
# 31     Alexandre Letellier  fr FRA    GK  32-153
# 32            Keylor Navas  cr CRC    GK  36-149
# 33             Serif Nhaga  pt POR    DF  17-254
# 34             Sergio Rico  es ESP    GK  29-254
# 35             Squad Total     NaN   NaN    27.6
# 36          Opponent Total     NaN   NaN    26.8

# %%
#suppression de NaN
psg = psg.dropna()

# %%
psg['Nation'] = psg['Nation'].str.replace('[a-z]', '', regex=True)
psg
# Out:
#                     Player Nation   Pos     Age
# 1     Gianluigi Donnarumma    ITA    GK  24-077
# 2               Marquinhos    BRA    DF  28-364
# 3             Lionel Messi    ARG  FWMF  35-323
# 4            Kylian Mbappé    FRA    FW  24-144
# 5             Sergio Ramos    ESP    DF  37-044
# 6                  Vitinha    POR    MF  23-089
# 7           Danilo Pereira    POR  DFMF  31-246
# 8           Marco Verratti    ITA    MF  30-189
# 9            Achraf Hakimi    MAR  DFMF  24-190
# 10        Fabián Ruiz Peña    ESP    MF  27-040
# 11             Nuno Mendes    POR    DF  20-328
# 12                  Neymar    BRA  MFFW  31-097
# 13             Juan Bernat    ESP    DF  30-073
# 14            Carlos Soler    ESP    MF  26-131
# 15           Nordi Mukiele    FRA    DF  25-193
# 16            Hugo Ekitike    FRA    FW  20-327
# 17        Presnel Kimpembe    FRA    DF  27-273
# 18      Warren Zaire-Emery    FRA  MFDF  17-066
# 19          Renato Sanches    POR    MF  25-268
# 20  El Chadaille Bitshiabu    FRA    DF  17-362
# 21        Timothee Pembele    FRA    DF  20-246
# 22           Pablo Sarabia    ESP  FWMF  31-002
# 23           Ismaël Gharbi    ESP  MFFW  19-033
# 24         Leandro Paredes    ARG    MF  28-318
# 25            Ilyes Housni    FRA    FW  17-364
# 26            Abdou Diallo    SEN    DF  27-009
# 27      Nehemiah Fernandez    FRA    DF  18-153
# 28       Arnaud Kalimuendo    FRA    FW  21-113
# 29              Ayman Kari    FRA    MF  18-175
# 30               Hugo Lamy    FRA    DF  19-117
# 31     Alexandre Letellier    FRA    GK  32-153
# 32            Keylor Navas    CRC    GK  36-149
# 33             Serif Nhaga    POR    DF  17-254
# 34             Sergio Rico    ESP    GK  29-254

# %%
#traitement colonne age

psg['Age'] = psg['Age'].str.slice(stop=2)
psg.head()
# Out:
#                  Player Nation   Pos Age
# 1  Gianluigi Donnarumma    ITA    GK  24
# 2            Marquinhos    BRA    DF  28
# 3          Lionel Messi    ARG  FWMF  35
# 4         Kylian Mbappé    FRA    FW  24
# 5          Sergio Ramos    ESP    DF  37

# %%
psg['Nation'] = psg['Nation'].str.strip()

# %%
#remplacement des codes pays

pays ={"AFG": "Afghanistan",
    "ALB": "Albanie",
    "ALG": "Algérie",
    "AND": "Andorre",
    "ANG": "Angola",
    "ANT": "Antigua-et-Barbuda",
    "ARG": "Argentine",
    "ARM": "Arménie",
    "ARU": "Aruba",
    "ASA": "Samoa américaines",
    "AUS": "Australie",
    "AUT": "Autriche",
    "AZE": "Azerbaïdjan",
    "BAH": "Bahamas",
    "BAN": "Bangladesh",
    "BAR": "Barbade",
    "BDI": "Burundi",
    "BEL": "Belgique",
    "BEN": "Bénin",
    "BER": "Bermudes",
    "BHU": "Bhoutan",
    "BIH": "Bosnie-Herzégovine",
    "BIZ": "Belize",
    "BLR": "Biélorussie",
    "BOL": "Bolivie",
    "BOT": "Botswana",
    "BRA": "Brésil",
    "BRN": "Bahreïn",
    "BRU": "Brunei",
    "BUL": "Bulgarie",
    "BUR": "Burkina Faso",
    "CAF": "République centrafricaine",
    "CAM": "Cambodge",
    "CAN": "Canada",
    "CAY": "Îles Caïmans  Îles Caïmans",
    "CGO": "République du Congo",
    "CHA": "Tchad",
    "CHI": "Chili",
    "CHN": "Chine, République populaire de",
    "CIV": "Côte d'Ivoire",
    "CMR": "Cameroun",
    "COD": "République démocratique du Congo",
    "COK": "Îles Cook",
    "COL": "Colombie",
    "COM": "Comores",
    "COR": "Corée unifiée",
    "CPV": "Cap-Vert",
    "CRC": "Costa Rica",
    "CRO": "Croatie",
    "CUB": "Cuba",
    "CYP": "Chypre",
    "RTCN": "Chypre du Nord",
    "CZE": "Tchéquie",
    "DEN": "Danemark",
    "DJI": "Djibouti",
    "DMA": "Dominique",
    "DOM": "République dominicaine",
    "ECU": "Équateur",
    "EGY": "Égypte",
    "ERI": "Érythrée",
    "ESA": "Salvador",
    "ESP": "Espagne",
    "EST": "Estonie",
    "ETH": "Éthiopie",
    "FIJ": "Fidji",
    "FIN": "Finlande",
    "FRA": "France",
    "FSM": "États fédérés de Micronésie",
    "GAB": "Gabon",
    "GAM": "Gambie",
    "GBR": "Grande-Bretagne",
    "GBS": "Guinée-Bissau",
    "GEO": "Géorgie",
    "GEQ": "Guinée équatoriale",
    "GER": "Allemagne",
    "GHA": "Ghana",
    "GRE": "Grèce",
    "GRN": "Grenade",
    "GUA": "Guatemala",
    "GUI": "Guinée",
    "GUM": "Guam",
    "GUY": "Guyana",
    "HAI": "Haïti",
    "HKG": "Hong Kong",
    "HON": "Honduras",
    "HUN": "Hongrie",
    "INA": "Indonésie",
    "IND": "Inde",
    "IRI": "Iran  Iran",
    "IRL": "Irlande",
    "IRQ": "Irak",
    "ISL": "Islande",
    "ISR": "Israël",
    "ISV": "Îles Vierges des États-Unis",
    "ITA": "Italie",
    "IVB": "Îles Vierges britanniques",
    "JAM": "Jamaïque",
    "JOR": "Jordanie",
    "JPN": "Japon",
    "KAZ": "Kazakhstan",
    "KEN": "Kenya",
    "KGZ": "Kirghizistan",
    "KIR": "Kiribati",
    "KOS": "Kosovo",
    "KOR": "Corée du Sud",
    "KSA": "Arabie saoudite",
    "KUW": "Koweït",
    "LAO": "Laos",
    "LAT": "Lettonie",
    "LBA": "Libye",
    "LBN": "Liban",
    "LBR": "Liberia",
    "LCA": "Sainte-Lucie",
    "LES": "Lesotho",
    "LIE": "Liechtenstein",
    "LTU": "Lituanie",
    "LUX": "Luxembourg",
    "MAD": "Madagascar",
    "MAR": "Maroc",
    "MAS": "Malaisie",
    "MAW": "Malawi",
    "MDA": "Moldavie",
    "MDV": "Maldives",
    "MEX": "Mexique",
    "MGL": "Mongolie",
    "MHL": "Îles Marshall",
    "MKD": "Macédoine du Nord",
    "MLI": "Mali",
    "MLT": "Malte",
    "MNE": "Monténégro",
    "MON": "Monaco",
    "MOZ": "Mozambique",
    "MRI": "Maurice",
    "MTN": "Mauritanie",
    "MYA": "Birmanie",
    "NAM": "Namibie",
    "NCA": "Nicaragua",
    "NED": "Pays-Bas",
    "NEP": "Népal",
    "NGR": "Nigeria",
    "NIG": "Niger",
    "NOR": "Norvège",
    "NRU": "Nauru",
    "NZL": "Nouvelle-Zélande",
    "OAR": "Athlètes olympiques de Russie",
    "OMA": "Oman",
    "PAK": "Pakistan",
    "PAN": "Panama",
    "PAR": "Paraguay",
    "PER": "Pérou",
    "PHI": "Philippines",
    "PLE": "Palestine",
    "PLW": "Palaos",
    "PNG": "Papouasie-Nouvelle-Guinée",
    "POL": "Pologne",
    "POR": "Portugal",
    "PRK": "Corée du Nord",
    "PUR": "Porto Rico",
    "QAT": "Qatar",
    "ROC": "Comité olympique de Russie",
    "ROT": "Équipe olympique des réfugiés",
    "ROU": "Roumanie",
    "RSA": "Afrique du Sud",
    "RUS": "Russie, Fédération de",
    "RWA": "Rwanda",
    "SAM": "Samoa",
    "SEN": "Sénégal",
    "SEY": "Seychelles",
    "SGP": "Singapour",
    "SKN": "Saint-Christophe-et-Niévès",
    "SLE": "Sierra Leone",
    "SLO": "Slovénie",
    "SMR": "Saint-Marin",
    "SOL": "Îles Salomon",
    "SOM": "Somalie",
    "SRB": "Serbie",
    "SRI": "Sri Lanka",
    "SSD": "Soudan du Sud",
    "STP": "Sao Tomé-et-Principe",
    "SUD": "Soudan",
    "SUI": "Suisse",
    "SUR": "Suriname",
    "SVK": "Slovaquie",
    "SWE": "Suède",
    "SWZ": "Eswatini/Swaziland",
    "SYR": "Syrie",
    "TAN": "Tanzanie, République unie de",
    "TGA": "Tonga",
    "THA": "Thaïlande",
    "TJK": "Tadjikistan",
    "TKM": "Turkménistan",
    "TLS": "Timor oriental",
    "TOG": "Togo",
    "TPE": "Taipei chinois",
    "TTO": "Trinité-et-Tobago",
    "TUN": "Tunisie  Tunisie",
    "TUR": "Turquie",
    "TUV": "Tuvalu",
    "UAE": "Émirats arabes unis",
    "UGA": "Ouganda",
    "UKR": "Ukraine",
    "URU": "Uruguay",
    "USA": "États-Unis",
    "UZB": "Ouzbékistan",
    "VAN": "Vanuatu",
    "VEN": "Venezuela",
    "VIE": "Viêt Nam",
    "VIN": "Saint-Vincent-et-les-Grenadines",
    "YEM": "Yémen",
    "ZAM": "Zambie  Zambie",
    "ZIM": "Zimbabwe"
}

# %%
psg['Nation'] = psg['Nation'].map(pays)
psg
# Out:
#                     Player      Nation   Pos Age
# 1     Gianluigi Donnarumma      Italie    GK  24
# 2               Marquinhos      Brésil    DF  28
# 3             Lionel Messi   Argentine  FWMF  35
# 4            Kylian Mbappé      France    FW  24
# 5             Sergio Ramos     Espagne    DF  37
# 6                  Vitinha    Portugal    MF  23
# 7           Danilo Pereira    Portugal  DFMF  31
# 8           Marco Verratti      Italie    MF  30
# 9            Achraf Hakimi       Maroc  DFMF  24
# 10        Fabián Ruiz Peña     Espagne    MF  27
# 11             Nuno Mendes    Portugal    DF  20
# 12                  Neymar      Brésil  MFFW  31
# 13             Juan Bernat     Espagne    DF  30
# 14            Carlos Soler     Espagne    MF  26
# 15           Nordi Mukiele      France    DF  25
# 16            Hugo Ekitike      France    FW  20
# 17        Presnel Kimpembe      France    DF  27
# 18      Warren Zaire-Emery      France  MFDF  17
# 19          Renato Sanches    Portugal    MF  25
# 20  El Chadaille Bitshiabu      France    DF  17
# 21        Timothee Pembele      France    DF  20
# 22           Pablo Sarabia     Espagne  FWMF  31
# 23           Ismaël Gharbi     Espagne  MFFW  19
# 24         Leandro Paredes   Argentine    MF  28
# 25            Ilyes Housni      France    FW  17
# 26            Abdou Diallo     Sénégal    DF  27
# 27      Nehemiah Fernandez      France    DF  18
# 28       Arnaud Kalimuendo      France    FW  21
# 29              Ayman Kari      France    MF  18
# 30               Hugo Lamy      France    DF  19
# 31     Alexandre Letellier      France    GK  32
# 32            Keylor Navas  Costa Rica    GK  36
# 33             Serif Nhaga    Portugal    DF  17
# 34             Sergio Rico     Espagne    GK  29

# %%
#Changement des postes

position = {"GK":"Gardien",
            "DF":"Défenseur",
            "FWMF":"Milieu Offensif",
            "FW":"Attaquant",
            "MF":"Milieu Défensif",
            "DFMF":"Latéral",
            "MFFW":"Milieu Offensif",
            "MFDF":"Milieu Défensif"}

psg['Pos'] = psg['Pos'].map(position)
psg
# Out:
#                     Player      Nation              Pos Age
# 1     Gianluigi Donnarumma      Italie          Gardien  24
# 2               Marquinhos      Brésil        Défenseur  28
# 3             Lionel Messi   Argentine  Milieu Offensif  35
# 4            Kylian Mbappé      France        Attaquant  24
# 5             Sergio Ramos     Espagne        Défenseur  37
# 6                  Vitinha    Portugal  Milieu Défensif  23
# 7           Danilo Pereira    Portugal          Latéral  31
# 8           Marco Verratti      Italie  Milieu Défensif  30
# 9            Achraf Hakimi       Maroc          Latéral  24
# 10        Fabián Ruiz Peña     Espagne  Milieu Défensif  27
# 11             Nuno Mendes    Portugal        Défenseur  20
# 12                  Neymar      Brésil  Milieu Offensif  31
# 13             Juan Bernat     Espagne        Défenseur  30
# 14            Carlos Soler     Espagne  Milieu Défensif  26
# 15           Nordi Mukiele      France        Défenseur  25
# 16            Hugo Ekitike      France        Attaquant  20
# 17        Presnel Kimpembe      France        Défenseur  27
# 18      Warren Zaire-Emery      France  Milieu Défensif  17
# 19          Renato Sanches    Portugal  Milieu Défensif  25
# 20  El Chadaille Bitshiabu      France        Défenseur  17
# 21        Timothee Pembele      France        Défenseur  20
# 22           Pablo Sarabia     Espagne  Milieu Offensif  31
# 23           Ismaël Gharbi     Espagne  Milieu Offensif  19
# 24         Leandro Paredes   Argentine  Milieu Défensif  28
# 25            Ilyes Housni      France        Attaquant  17
# 26            Abdou Diallo     Sénégal        Défenseur  27
# 27      Nehemiah Fernandez      France        Défenseur  18
# 28       Arnaud Kalimuendo      France        Attaquant  21
# 29              Ayman Kari      France  Milieu Défensif  18
# 30               Hugo Lamy      France        Défenseur  19
# 31     Alexandre Letellier      France          Gardien  32
# 32            Keylor Navas  Costa Rica          Gardien  36
# 33             Serif Nhaga    Portugal        Défenseur  17
# 34             Sergio Rico     Espagne          Gardien  29
